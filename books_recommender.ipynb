# %% [markdown]
# ### Books recommender system using clustering | Collaborative based

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv('data/books_data/books.csv', sep=';', encoding='latin-1', on_bad_lines='skip')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_22196\1381155323.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('data/books_data/books.csv', sep=';', encoding='latin-1', on_bad_lines='skip')

# %%
books.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books = books.filter(items=['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher', 'Image-URL-L'])
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
books.rename(columns={"Book-Title": "title",
                       "Book-Author": "author",
                       "Year-Of-Publication": "year",
                       "Publisher": "publisher",
                       "Image-URL-L": "image_url"}, inplace=True)
books.head(1)
# Out:
#          ISBN                title              author  year  \
# 0  0195153448  Classical Mythology  Mark P. O. Morford  2002
#
#                  publisher                                          image_url
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...

# %%
users = pd.read_csv('data/books_data/users.csv', sep=';', encoding='latin-1', on_bad_lines='skip')
ratings = pd.read_csv('data/books_data/ratings.csv', sep=';', encoding='latin-1', on_bad_lines='skip')

# %%
users.head(2)
# Out:
#    User-ID                   Location   Age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %%
ratings.head(2)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5

# %%
users.rename(columns={"User-ID": "user_id",
                       "Location": "location",
                       "Age": "age"}, inplace=True)
users.head(2)
# Out:
#    user_id                   location   age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %%
ratings.rename(columns={"User-ID": "user_id",
                       "Book-Rating": "rating"}, inplace=True)
ratings.head(2)
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5

# %%
ratings['user_id'].value_counts()
# Out:
# user_id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %%
x = ratings['user_id'].value_counts() > 200
x[x].shape
# Out:
# (899,)

# %%
y = x[x].index
y
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#        260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727, 268622,
#        188951],
#       dtype='int64', name='user_id', length=899)

# %%
ratings = ratings[ratings['user_id'].isin(y)]
ratings.shape
# Out:
# (526356, 3)

# %%
rating_with_books = ratings.merge(books, on='ISBN')
rating_with_books.shape
# Out:
# (487671, 8)

# %%
rating_with_books.head(3)
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1   277427  0026217457       0
# 2   277427  003008685X       8
#
#                                                title                 author  \
# 0  Politically Correct Bedtime Stories: Modern Ta...      James Finn Garner
# 1                 Vegetarian Times Complete Cookbook             Lucy  Moll
# 2                                           Pioneers  James Fenimore Cooper
#
#    year                  publisher  \
# 0  1994  John Wiley &amp; Sons Inc
# 1  1995      John Wiley &amp; Sons
# 2  1974           Thomson Learning
#
#                                            image_url
# 0  http://images.amazon.com/images/P/002542730X.0...
# 1  http://images.amazon.com/images/P/0026217457.0...
# 2  http://images.amazon.com/images/P/003008685X.0...

# %%
num_ratings = rating_with_books.groupby('title')['rating'].count().reset_index()
num_ratings.rename(columns={'rating': 'num_ratings'}, inplace=True)
num_ratings.head()
# Out:
#                                                title  num_ratings
# 0   A Light in the Storm: The Civil War Diary of ...            2
# 1                              Always Have Popsicles            1
# 2               Apple Magic (The Collector's series)            1
# 3   Beyond IBM: Leadership Marketing and Finance ...            1
# 4   Clifford Visita El Hospital (Clifford El Gran...            1

# %%
final_rating = rating_with_books.merge(num_ratings, on='title')

# %%
final_rating.head(3)
final_rating.shape
# Out:
# (487671, 9)

# %%
final_rating = final_rating[final_rating['num_ratings'] >= 50]
final_rating.shape
# Out:
# (61853, 9)

# %%
final_rating.drop_duplicates(['user_id', 'title'], inplace=True)
final_rating.shape
# Out:
# (59850, 9)

# %%
books_pivot = final_rating.pivot_table(index='title', columns='user_id', values='rating')
books_pivot.fillna(0, inplace=True)
books_pivot.shape
# Out:
# (742, 888)

# %%
from scipy.sparse import csr_matrix

# %%
books_sparse = csr_matrix(books_pivot)
books_sparse.shape
# Out:
# (742, 888)

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model = NearestNeighbors(algorithm='brute')
model.fit(books_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
def get_book_recommendations(title, n_recommendations=5):
    book_index = books_pivot.index.get_loc(title)
    distances, indices = model.kneighbors(books_sparse[book_index], n_neighbors=n_recommendations + 1)

    recommended_books = []
    for i in range(1, len(distances.flatten())):
        recommended_books.append((books_pivot.index[indices.flatten()[i]], distances.flatten()[i]))

    return recommended_books

# Example usage
recommended_books = get_book_recommendations(books_pivot.index[237], n_recommendations=5)
print(recommended_books)
# Out:
# [('Harry Potter and the Goblet of Fire (Book 4)', 67.75691846593969), ('Harry Potter and the Prisoner of Azkaban (Book 3)', 68.05145112339633), ("Harry Potter and the Sorcerer's Stone (Book 1)", 72.27724399837061), ('Exclusive', 75.81556568409947), ('The Cradle Will Fall', 76.30203142774116)]

# %%
# store the name of the books
book_name = books_pivot.index
book_name.shape
# Out:
# (742,)

# %%
import pickle

# %%
pickle.dump(model, open('artifacts/model.pkl', 'wb'))
pickle.dump(book_name, open('artifacts/book_name.pkl', 'wb'))
pickle.dump(books_pivot, open('artifacts/books_pivot.pkl', 'wb'))
pickle.dump(final_rating, open('artifacts/final_rating.pkl', 'wb'))

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
pca = PCA(n_components=50)
pca_books = pca.fit_transform(books_sparse.toarray())

# %%
tsne = TSNE(n_components=2, random_state=30, perplexity=30)
tsne_books = tsne.fit_transform(pca_books)

# %%
plt.figure(figsize=(12, 8))
plt.scatter(tsne_books[:, 0], tsne_books[:, 1], alpha=0.5)
plt.title('Book Clusters based on User Ratings')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.grid(True)
# plt.show()

# %%
books.shape
# Out:
# (271360, 6)
